# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings("ignore", "is_categorical_dtype")
warnings.filterwarnings("ignore", "use_inf_as_na")

import math

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/dataset-environment-communities/Dataset_de_200_Comunidades_para_Analise_Ambiental.csv

# %% [markdown]
# # Exploratory Analysis

# %% [markdown]
# ## Overview

# %%
df = pd.read_csv('/kaggle/input/dataset-environment-communities/Dataset_de_200_Comunidades_para_Analise_Ambiental.csv', sep = ',')
df.head()
# Out:
#      Comunidade              Município Estado  Índice de Desmatamento (%)  \
# 0  Comunidade 1  SÃO DOMINGOS DO CAPIM   Pará                        25.6
# 1  Comunidade 2            SALINÓPOLIS   Pará                        12.9
# 2  Comunidade 3             TRACUATEUA   Pará                        81.3
# 3  Comunidade 4    SÃO MIGUEL DO GUAMÁ   Pará                        81.5
# 4  Comunidade 5       MAGALHÃES BARATA   Pará                        58.8
#
#    Acesso à Água Potável (%)  Cobertura Vegetal (%)  Renda Média Mensal (R$)  \
# 0                       86.5                   22.9                   2863.0
# 1                       99.3                   21.8                    799.0
# 2                       58.9                   64.5                   1924.0
# 3                       56.0                   25.5                   1715.0
# 4                       84.3                   39.4                   1990.0
#
# ...

# %%
df.shape
# Out:
# (200, 12)

# %%
df_null_cells = df.isnull().sum()
df_null_cells
# Out:
# Comunidade                                0
# Município                                 0
# Estado                                    0
# Índice de Desmatamento (%)                0
# Acesso à Água Potável (%)                 0
# Cobertura Vegetal (%)                     0
# Renda Média Mensal (R$)                   0
# Densidade Populacional (hab/km²)          0
# Frequência de Queimadas (ano)             0
# Distância de Área Urbana (km)             0
# Presença de Escola (Sim/Não)              0
# Presença de Unidade de Saúde (Sim/Não)    0
# dtype: int64

# %%
verify_unique_values = df.nunique()
verify_unique_values
# Out:
# Comunidade                                200
# Município                                 101
# Estado                                      1
# Índice de Desmatamento (%)                175
# Acesso à Água Potável (%)                 170
# Cobertura Vegetal (%)                     182
# Renda Média Mensal (R$)                   191
# Densidade Populacional (hab/km²)          189
# Frequência de Queimadas (ano)              12
# Distância de Área Urbana (km)             187
# Presença de Escola (Sim/Não)                2
# Presença de Unidade de Saúde (Sim/Não)      2
# dtype: int64

# %% [markdown]
# ### Data Types

# %%
df_types_values = df.dtypes
df_types_values
# Out:
# Comunidade                                 object
# Município                                  object
# Estado                                     object
# Índice de Desmatamento (%)                float64
# Acesso à Água Potável (%)                 float64
# Cobertura Vegetal (%)                     float64
# Renda Média Mensal (R$)                   float64
# Densidade Populacional (hab/km²)          float64
# Frequência de Queimadas (ano)               int64
# Distância de Área Urbana (km)             float64
# Presença de Escola (Sim/Não)               object
# Presença de Unidade de Saúde (Sim/Não)     object
# dtype: object

# %%
df_object_features = df.select_dtypes(include='object')
df_object_features
# Out:
#          Comunidade              Município Estado  \
# 0      Comunidade 1  SÃO DOMINGOS DO CAPIM   Pará
# 1      Comunidade 2            SALINÓPOLIS   Pará
# 2      Comunidade 3             TRACUATEUA   Pará
# 3      Comunidade 4    SÃO MIGUEL DO GUAMÁ   Pará
# 4      Comunidade 5       MAGALHÃES BARATA   Pará
# ..              ...                    ...    ...
# 195  Comunidade 196       MOJUÍ DOS CAMPOS   Pará
# 196  Comunidade 197           PORTO DE MOZ   Pará
# 197  Comunidade 198                TUCURUÍ   Pará
# 198  Comunidade 199                 CURUÇÁ   Pará
# 199  Comunidade 200                  VIGIA   Pará
#
#     Presença de Escola (Sim/Não) Presença de Unidade de Saúde (Sim/Não)
# 0                            Sim                                    Não
# 1                            Sim                                    Não
# 2                            Não                                    Sim
# 3                            Sim                                    Sim
# ...

# %%
numeric_floats_features = df.select_dtypes(include='float')
numeric_floats_features
# Out:
#      Índice de Desmatamento (%)  Acesso à Água Potável (%)  \
# 0                          25.6                       86.5
# 1                          12.9                       99.3
# 2                          81.3                       58.9
# 3                          81.5                       56.0
# 4                          58.8                       84.3
# ..                          ...                        ...
# 195                        67.5                       74.3
# 196                        73.3                       46.8
# 197                        29.0                       35.3
# 198                        20.1                       39.0
# 199                        68.8                       39.0
#
#      Cobertura Vegetal (%)  Renda Média Mensal (R$)  \
# 0                     22.9                   2863.0
# 1                     21.8                    799.0
# 2                     64.5                   1924.0
# ...

# %%
numeric_int_features = df.select_dtypes(include='int')
numeric_int_features
# Out:
#      Frequência de Queimadas (ano)
# 0                                0
# 1                               11
# 2                                5
# 3                                0
# 4                                9
# ..                             ...
# 195                              2
# 196                              9
# 197                              2
# 198                              6
# 199                              3
#
# [200 rows x 1 columns]

# %% [markdown]
# ## Descriptive statistics

# %% [markdown]
# ### Categorical Variables

# %%
df_object_features.describe()
# Out:
#           Comunidade  Município Estado Presença de Escola (Sim/Não)  \
# count            200        200    200                          200
# unique           200        101      1                            2
# top     Comunidade 1  RURÓPOLIS   Pará                          Sim
# freq               1          5    200                          155
#
#        Presença de Unidade de Saúde (Sim/Não)
# count                                     200
# unique                                      2
# top                                       Sim
# freq                                      119

# %%
print("Tabela de contingência: Município vs. Presença de Escola")
pd.crosstab(df['Município'], df['Presença de Escola (Sim/Não)'], margins=True)
# Out:
# Tabela de contingência: Município vs. Presença de Escola
# Presença de Escola (Sim/Não)  Não  Sim  All
# Município
# ACARÁ                           0    2    2
# ALENQUER                        1    1    2
# ALMEIRIM                        0    1    1
# ALTAMIRA                        0    1    1
# ANAJÁS                          0    2    2
# ...                           ...  ...  ...
# VIGIA                           0    5    5
# VITÓRIA DO XINGU                0    1    1
# XINGUARA                        0    1    1
# ÓBIDOS                          0    2    2
# All                            45  155  200
#
# [102 rows x 3 columns]

# %% [markdown]
# ### Maximum value of schools in a community

# %%
max_value_school = pd.crosstab(df['Município'], df['Presença de Escola (Sim/Não)'], margins=True)
max_value_school = max_value_school.drop('All')
max_value_school['Sim'].max()
# Out:
# 5

# %% [markdown]
# ### Numeric Variables

# %%
df_numeric_final = pd.concat([numeric_floats_features, numeric_int_features])
df_numeric_final_describe = df_numeric_final.describe()
df_numeric_final_describe
# Out:
#        Índice de Desmatamento (%)  Acesso à Água Potável (%)  \
# count                  200.000000                 200.000000
# mean                    47.588000                  67.678000
# std                     25.011311                  21.344876
# min                      5.400000                  30.800000
# 25%                     26.000000                  51.400000
# 50%                     51.050000                  68.700000
# 75%                     67.550000                  86.925000
# max                     89.200000                 100.000000
#
#        Cobertura Vegetal (%)  Renda Média Mensal (R$)  \
# count              200.00000               200.000000
# mean                49.45950              1614.530000
# std                 23.47915               746.032763
# min                 11.70000               412.000000
# 25%                 27.72500               944.750000
# 50%                 47.65000              1576.000000
# ...

# %% [markdown]
# ## Identifying outliers

# %%
num_colunas = len(df_numeric_final)

num_cols_grid = 3 
num_rows_grid = math.ceil(num_colunas / num_cols_grid)

fig, axes = plt.subplots(num_rows_grid, num_cols_grid, figsize=(num_cols_grid * 6, num_rows_grid * 4))
axes = axes.flatten()

for i, col in enumerate(df_numeric_final):
    sns.boxplot(y=df[col], ax=axes[i])
    axes[i].set_title(col)
    axes[i].set_ylabel('')

for j in range(i + 1, len(axes)):
    fig.delaxes(axes[j])

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Comparing the data

# %%
num_colunas = len(df_object_features.iloc[:, 3:].columns)

num_cols_grid = 3
num_rows_grid = math.ceil(num_colunas / num_cols_grid)

fig, axes = plt.subplots(num_rows_grid, num_cols_grid, figsize=(num_cols_grid * 6, num_rows_grid * 5))
axes = axes.flatten()

for i, col in enumerate(df_object_features.iloc[:, 3:].columns):
    counts = df[col].value_counts()
    labels = counts.index
    sizes = counts.values

    axes[i].pie(sizes, labels=labels, autopct='%1.1f%%', startangle=90, pctdistance=0.85)
    
    centre_circle = plt.Circle((0,0),0.70,fc='white')
    axes[i].add_artist(centre_circle)
    
    axes[i].axis('equal')  
    
    axes[i].set_title(col)

for j in range(i + 1, len(axes)):
    fig.delaxes(axes[j])

plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x=df['Presença de Escola (Sim/Não)'], y=df['Frequência de Queimadas (ano)'])
plt.title('Dist. de Frequência de Queimada em Reigões que há escolas', fontsize=16)
plt.xlabel('Presença de Escola (Sim/Não)', fontsize=12)
plt.ylabel('Frequência de Queimadas (ano)', fontsize=12)
plt.grid(axis='y', linestyle='--', alpha=0.7) # Adiciona uma grade no eixo Y
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x=df['Presença de Unidade de Saúde (Sim/Não)'], y=df['Frequência de Queimadas (ano)'])
plt.title('Dist. de Frequência de Queimada em Regiões que há U. de Saúde', fontsize=16)
plt.xlabel('Presença de Escola (Sim/Não)', fontsize=12)
plt.ylabel('Frequência de Queimadas (ano)', fontsize=12)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %%
plt.figsize=(10, 8)
sns.histplot(x=df[numeric_int_features.columns[0]], bins=10)
plt.ylabel('Frequência')
plt.title('Frequência de Queimadas x Comunidade', fontsize=14)
# Out:
# Text(0.5, 1.0, 'Frequência de Queimadas x Comunidade')

# %%
plt.figure(figsize=(10, 6))
sns.regplot(x = 'Acesso à Água Potável (%)', y = 'Índice de Desmatamento (%)', data = df)
plt.title('Acesso a Água (%) x Índice de Desmatamento (ano)', fontsize=14)
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.regplot(x='Acesso à Água Potável (%)', y='Frequência de Queimadas (ano)', data=df)
plt.title('Acesso a Água (%) x Frequência de Queimadas (ano)', fontsize=14)
plt.show()

# %% [markdown]
# ## Correlation Map

# %%
df_features = df.iloc[:, 3:10]

# %%
plt.figure(figsize=(12, 10))
sns.heatmap(df_features.corr(), annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Mapa de Calor de Correlação')
plt.show()
